# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# ax+by+cz=d
# a,b,c,d = .0199253, .0003865, -1, -187.8645 #1bed
a,b,c,d = .0746718, -.0000547, -1, 4360.645 #2bed
# a,b,c,d = -.0365631, .0011282, -1, -7129.59 #3bed

x = np.linspace(-1,1,10)
y = np.linspace(-1,1,10)

X,Y = np.meshgrid(x,y)
Z = (d - a*X - b*Y) / c

fig = plt.figure()
ax = fig.gca(projection='3d')


# Switch the 3 below for camera angle
ax.azim = -80
ax.dist = 10
ax.elev = 30

surf = ax.plot_surface(X, Y, Z)

# %%
ax.figure.savefig('file.png', dpi=400)
